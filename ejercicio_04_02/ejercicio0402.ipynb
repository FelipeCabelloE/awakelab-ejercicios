# %% [markdown]
# Caso 1: variable Aleatoria en Distribución normal
# Si es una variable aleatoria de una distribución N(u,o),
# hallar: P(u-3o <= X <= u + 3o).
#
# Z = (u - 3o - u) / o = 3
#
# para Z = 3 en la tabla obtenemos 99.7 porciento de los datos
#
#
#
# Caso 2: Distribución normal, media y desviación típica
# En una distribución normal de media 4 y desviación típica 2, calcular el valor de a para
# que: P(4 - a <= x <= 4 + a) = 0.5934
#
# Z = (X - μ) / σ
# osea
# Z = (X - 4) / 2
# Z = (4 - a - 4) / 2 = -a/2 # Lo mismo para el a positivo
#
# P(-a/2 <= Z <= a/2) = 0.5934
# 0.5934 / 2 = 0.2967
#
# en la tabla 0.2967 es 0.83,
#
# La res´puesta es 0.83*2
#
# osea 1.66
#
#
#
# Caso 3: Distribución Normal
# Dada una variable aleatoria continua Z, con distribución normal estándar, es decir, N(0;1),
# encuentre las siguientes probabilidades, usando la tabla.
#
# Tabla-z-distribució
# n-normal-estandariz
#
# a) P(0 ≤ Z ≤ 1.25) = P(Z ≤ 1.25) - P(Z ≤ 0) = 0.8944 - 0.5 = 0.3944
#
# b) P(Z ≥ 1.25) = 1 - P(Z < 1.25) = 1 - 0.8944 = 0.1056
#
# c) P(Z ≤ -1.25) = P(Z ≥ 1.25) (simetría alrededor de 0) = 0.1056
#
# d) P(0 ≤ Z ≤ 1.33) = P(Z ≤ 1.33) - P(Z ≤ 0) = 0.9073 - 0.5 = 0.4073
#
# e) P(Z ≥ 1.33) = 1 - P(Z < 1.33) = 1 - 0.9073 = 0.0927
#
# f) P(-1.33 ≤ Z ≤ 0) = P(Z ≤ 0) - P(Z ≤ -1.33) = 0.5 - 0.0927 = 0.4073
#
#
# Caso 4: Distribución Binomial.
# Uno de los ítems de una prueba sorpresa consta de 12 preguntas de verdadero o falso.
# Suponiendo que los estudiantes no saben contestar a ninguna de ellas y, contestan al
# azar, hallar la probabilidad de obtener seis aciertos.
#
#
# C(12, 6) = 12! / [6!(12-6)!]
#
# P(X=6) = C(12, 6) * (0.5^6) * (0.5^6) = 924 * (0.5^12) ≈ 0.2256
