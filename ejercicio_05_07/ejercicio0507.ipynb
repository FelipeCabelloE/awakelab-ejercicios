# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url_train = 'https://raw.githubusercontent.com/natjulian/Contribuci-n-Diplomado-Data-Science-UC-2021/main/Bases%20de%20datos%20Clases/Activity/train.csv'

url_test = 'https://raw.githubusercontent.com/natjulian/Contribuci-n-Diplomado-Data-Science-UC-2021/main/Bases%20de%20datos%20Clases/Activity/test.csv'

# Cargar los datos
train = pd.read_csv(url_train)
test = pd.read_csv(url_test)
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X
# 0           0.288585          -0.020294          -0.132905         -0.995279  \
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y
# 0         -0.983111         -0.913526         -0.995112         -0.983185  \
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
# Verificar los datos
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X
# 0           0.288585          -0.020294          -0.132905         -0.995279  \
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y
# 0         -0.983111         -0.913526         -0.995112         -0.983185  \
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
print(train.dtypes.value_counts())
print(test.dtypes.value_counts())
# Out:
# float64    561
# int64        1
# object       1
# Name: count, dtype: int64
# float64    561
# int64        1
# object       1
# Name: count, dtype: int64

# %%
print(train.isna().sum().sum())
print()
print(test.isna().sum().sum())
# Out:
# 0
#
# 0

# %%
print(train.shape)
print(test.shape)
# Out:
# (7352, 563)
# (2947, 563)

# %%
######################### Comparar tipos de datos de df's  #########################

# Obtener los tipos de datos de cada DataFrame
#===============================================================================
dtypes1 = train.dtypes
dtypes2 = test.dtypes

# Comparar los tipos de datos columna por columna
#==============================================================================
diferentes = []
for columna in dtypes1.index:
    if dtypes1[columna] != dtypes2[columna]:
        diferentes.append(columna)

# Imprimir las columnas con tipos de datos diferentes
#==============================================================================
if len(diferentes) == 0:
    print("Los tipos de datos son iguales en todas las columnas.")
else:
    print("Los tipos de datos son diferentes en las siguientes columnas:")
    for columna in diferentes:
        print(columna)
# Out:
# Los tipos de datos son iguales en todas las columnas.

# %%
pd.crosstab(test['Activity'], columns='count', normalize=True)
# Out:
# col_0                  count
# Activity
# LAYING              0.182219
# SITTING             0.166610
# STANDING            0.180523
# WALKING             0.168307
# WALKING_DOWNSTAIRS  0.142518
# WALKING_UPSTAIRS    0.159824

# %%
pd.crosstab(train['Activity'], columns='count', normalize=True).reset_index()
# Out:
# col_0            Activity     count
# 0                  LAYING  0.191376
# 1                 SITTING  0.174918
# 2                STANDING  0.186888
# 3                 WALKING  0.166757
# 4      WALKING_DOWNSTAIRS  0.134113
# 5        WALKING_UPSTAIRS  0.145947

# %%
sns.barplot(x=pd.crosstab(test['Activity'], columns='count', normalize=True).reset_index()['Activity'], y=pd.crosstab(test['Activity'], columns='count', normalize=True).reset_index()['count'])
# Out:
# <Axes: xlabel='Activity', ylabel='count'>

# %%
sns.barplot(x=pd.crosstab(train['Activity'], columns='count', normalize=True).reset_index()['Activity'], y=pd.crosstab(train['Activity'], columns='count', normalize=True).reset_index()['count'])
# Out:
# <Axes: xlabel='Activity', ylabel='count'>

# %%
train
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z
# 0              0.288585          -0.020294          -0.132905  \
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X
# 0            -0.995279         -0.983111         -0.913526         -0.995112  \
# ...

# %% [markdown]
# La distribución es similar en el train y test set, ademàs entre las categorías también

# %%
# split x and y

from json import encoder
from sklearn.discriminant_analysis import StandardScaler


X_train = train.drop(['Activity', 'subject'], axis=1)
X_test = test.drop(['Activity', 'subject'], axis=1)
# encode y_train and y_test

from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

y_train = encoder.fit_transform(train['Activity'])
y_test = encoder.fit_transform(test['Activity'])

# Initialize the standard scaler
scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(X_train)
x_test_scaled = scaler.fit_transform(X_test)

# %%
# Create a Random Forest classifier
from sklearn.ensemble import RandomForestClassifier


rf = RandomForestClassifier(
    n_estimators=1000,
    random_state=0
)

# Train the classifier
rf.fit(x_train_scaled, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=0)

# %%
rf.score(x_test_scaled, y_test)
# Out:
# 0.9239904988123515

# %% [markdown]
# No son muy claros en qué modelo o parámetros utilizar. Lo más directo es hacer un random forest

# %%
from sklearn import tree
# Get the decision tree structure from the Random Forest
trees = rf.estimators_

# Visualize the first decision tree in the Random Forest
fig, ax = plt.subplots(figsize=(12, 8))
ax.set_axis_off()
_ = tree.plot_tree(
    trees[-1],
    feature_names=train.drop(['Activity', 'subject'], axis=1).columns,
    class_names=train['Activity'].unique(),
    filled=True
)
#save the figure high resolution
fig.savefig('rf_individualtree.png', dpi=300)
